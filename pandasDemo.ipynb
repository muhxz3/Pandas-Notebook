# %% [markdown]
# <a href="https://colab.research.google.com/github/muhxz3/Pandas-Notebook/blob/main/pandasDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
python_scores = {
    "Riya": 43, "Fiza": 38, "Saurab":37
}

s = pd.Series(python_scores)

# %%
s
# Out:
# Riya      43
# Fiza      38
# Saurab    37
# dtype: int64

# %%
print(type(s))
# Out:
# <class 'pandas.core.series.Series'>

# %%
cars = {
    "name": ["Benz","MG","Audi","Merc"],
    "rating": [6,7,8,9]
}

df = pd.DataFrame(cars)

# %%
df
# Out:
#    name  rating
# 0  Benz       6
# 1    MG       7
# 2  Audi       8
# 3  Merc       9

# %%
# create a dataframe from a numpy array

import numpy as np

a = np.array([[1,2],[3,4],[5,6]])
df = pd.DataFrame(a)
df
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
print(df.to_numpy())
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv",usecols=["longitude"])

df.to_csv("new_file.csv")
